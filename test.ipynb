# %%
import numpy as np

data = [1,10,7,2,4]
y = np.array([1,1,1,0,0])
k=3

index = np.argsort(data)[::-1][:k]

y[index]
# Out:
# array([1, 1, 0])

# %%
x = [1,2,3,2,6,7,3,4,5,6]
values, counts = np.unique(x, return_counts=True)

values[np.argmax(counts)]
# Out:
# np.int64(2)
